# %%
import pandas as pd
import matplotlib.pylab as plt

# %%
url = "input.csv"
df = pd.read_csv(url, header=0)

# %%
df.head(10)
# Out:
#    numero_cliente fecha_inspeccion  comuna                 distrito  \
# 0          796155       03/01/2018    34.0                SURQUILLO
# 1         1777374       03/01/2018    34.0                SURQUILLO
# 2         1452317       03/01/2018    33.0        SANTIAGO DE SURCO
# 3          310723       03/01/2018     8.0               CHACLACAYO
# 4         1530661       04/01/2018    33.0        SANTIAGO DE SURCO
# 5          391583       04/01/2018    33.0        SANTIAGO DE SURCO
# 6          784115       04/01/2018     9.0               CHORRILLOS
# 7          938610       05/01/2018    12.0                LA MOLINA
# 8          360213       08/01/2018    35.0  VILLA MARIA DEL TRIUNFO
# 9           95403       08/01/2018    18.0               MIRAFLORES
#
#    actividad actividad_descripcion  categoria giro_suministro tarifa  \
# 0        1.0                  CASA        0.0           P9500    BT5
# 1        7.0               BODEGAS        1.0           G5211    BT5
# 2        2.0          DEPARTAMENTO        0.0           P9500    BT5
# 3        1.0                  CASA        0.0           P9500    BT5
# 4        1.0                  CASA        0.0           P9500    BT5
# 5        1.0                  CASA        0.0           P9500    BT5
# 6        1.0                  CASA        0.0           P9500    BT5
# 7        1.0                  CASA        0.0           P9500    BT5
# 8        1.0                  CASA        0.0           P9500    BT5
# 9        7.0               BODEGAS        1.0           G5211    BT5
#
#    clave_tarifa  ...     c15     c16     c17     c18    c19    c20    c21  \
# 0          21.0  ...  1624.5  1538.1  1525.1   700.9  587.3  600.9  579.7
# 1          21.0  ...   357.8   339.6   318.3   181.7   94.0   76.4   72.7
# 2          21.0  ...   471.7   474.5   417.4     0.0    0.0    0.0    0.0
# 3          21.0  ...   207.0   230.0   189.0   230.0  276.0  281.0  303.0
# 4          21.0  ...   429.0   289.0   118.0    80.0   87.0  103.0   93.0
# 5          21.0  ...    85.4    95.3   112.8   124.1  107.0  101.3  102.3
# 6          21.0  ...   349.9   395.3   466.2   282.0  267.1  250.7  415.3
# 7          21.0  ...   272.0   249.0   236.1   189.9  211.1   16.6    0.0
# 8          21.0  ...   608.8   448.6    82.1    82.7  188.1  214.1  206.8
# 9          21.0  ...   687.2   519.5   882.3  1111.6  753.5  483.5  547.1
#
#      c22    c23    c24
# 0  658.2  777.3  737.6
# 1   89.8  146.9  182.9
# 2    0.0  343.0  757.3
# 3  239.0  255.0  306.0
# 4  106.0  123.0  110.0
# 5  124.8   97.7  111.3
# 6  493.4  480.2  477.1
# 7    0.0    0.1    0.0
# 8  239.9  204.7  192.5
# 9  378.0  485.4  485.7
#
# [10 rows x 91 columns]

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
fig, ax = pyplot.subplots(figsize =(17, 20))
ax.barh(df['distrito'].unique().tolist(), df["distrito"].value_counts(), align='center')
ax.grid(b = True, color ='grey',linestyle ='-.', linewidth = 0.5, alpha = 0.2)
for i in ax.patches:
    plt.pyplot.text(i.get_width()+0.2, i.get_y()+0.25, str(round((i.get_width()), 2)),fontsize = 10, fontweight ='bold',color ='grey')
# establece las etiquetas x/y y muestra el título 
plt.pyplot.xlabel("Cantidad")
plt.pyplot.ylabel("Distrito")
plt.pyplot.title("Hurto por Distrito")
# Out:
# Text(0.5, 1.0, 'Hurto por Distrito')

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
fig, ax = pyplot.subplots(figsize =(11, 10))
ax.barh(df['sucursal'].unique().tolist(), df["sucursal"].value_counts(), align='center')
ax.grid(b = True, color ='grey',linestyle ='-.', linewidth = 0.5, alpha = 0.2)
for i in ax.patches:
    plt.pyplot.text(i.get_width()+0.2, i.get_y()+0.25, str(round((i.get_width()), 2)),fontsize = 10, fontweight ='bold',color ='grey')
# establece las etiquetas x/y y muestra el título 
plt.pyplot.xlabel("Cantidad")
plt.pyplot.ylabel("Sucursal")
plt.pyplot.title("Hurto por Sucursal")
# Out:
# Text(0.5, 1.0, 'Hurto por Sucursal')

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
fig, ax = pyplot.subplots(figsize =(11, 5))
ax.barh(df['tarifa'].unique().tolist(), df["tarifa"].value_counts(), align='center')
ax.grid(b = True, color ='grey',linestyle ='-.', linewidth = 0.5, alpha = 0.2)
for i in ax.patches:
    plt.pyplot.text(i.get_width()+0.2, i.get_y()+0.25, str(round((i.get_width()), 2)),fontsize = 10, fontweight ='bold',color ='grey')
# establece las etiquetas x/y y muestra el título 
plt.pyplot.xlabel("Cantidad")
plt.pyplot.ylabel("Tarifa")
plt.pyplot.title("Hurto por Tarifa")
# Out:
# Text(0.5, 1.0, 'Hurto por Tarifa')

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
fig, ax = pyplot.subplots(figsize =(11, 13))
ax.barh(df['actividad_descripcion'].unique().tolist(), df["actividad_descripcion"].value_counts(), align='center')
ax.grid(b = True, color ='grey',linestyle ='-.', linewidth = 0.5, alpha = 0.2)
for i in ax.patches:
    plt.pyplot.text(i.get_width()+0.2, i.get_y()+0.25, str(round((i.get_width()), 2)),fontsize = 10, fontweight ='bold',color ='grey')
# establece las etiquetas x/y y muestra el título 
plt.pyplot.xlabel("Cantidad")
plt.pyplot.ylabel("Actividad")
plt.pyplot.title("Hurto por Actividad")
# Out:
# Text(0.5, 1.0, 'Hurto por Actividad')
